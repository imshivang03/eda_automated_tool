# %% [markdown]
# # EDA using autoviz (Automated Tool)

# %%
pip install autoviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("E://Technical//DS_AI_ML//ineuron_internship//eda&feature_engineering_learning//dataset/data0//aug_test.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
import seaborn as sns

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class. Call by using AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)

# %%
AV= AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = 'E://Technical//DS_AI_ML//ineuron_internship//eda&feature_engineering_learning//dataset/data0//aug_test.csv'
dft = AV.AutoViz(filename, target, df, header=0, verbose=0, lowess=False, chart_format='svg', max_rows_analyzed=150000, max_cols_analyzed=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13388/3859047284.py in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 filename = 'E://Technical//DS_AI_ML//ineuron_internship//eda&feature_engineering_learning//dataset/data0//aug_test.csv'
# ----> 4 dft = AV.AutoViz(filename, target, df, header=0, verbose=0, lowess=False, chart_format='svg', max_rows_analyzed=150000, max_cols_analyzed=30)
#
# NameError: name 'target' is not defined

# %%
dft
# Out:
#       city_development_index  gender      relevent_experience  \
# 0                      0.827    Male  Has relevent experience
# 1                      0.920  Female  Has relevent experience
# 2                      0.624    Male   No relevent experience
# 3                      0.827    Male  Has relevent experience
# 4                      0.920    Male  Has relevent experience
# ...                      ...     ...                      ...
# 2124                   0.920    Male   No relevent experience
# 2125                   0.897    Male  Has relevent experience
# 2126                   0.887    Male   No relevent experience
# 2127                   0.804    Male  Has relevent experience
# 2128                   0.804    Male  Has relevent experience
#
#      enrolled_university education_level major_discipline company_size  \
# 0       Full time course        Graduate             STEM          <10
# 1          no_enrollment        Graduate             STEM          NaN
# ...
